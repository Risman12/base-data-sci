# %%
import matplotlib.pyplot as plt

# %%
print("--soal no1--")
print()
s2_a= 0
s2_b= 1
s2_c= 4
s2_d= 7
s2_e= 5
s2_f= 0
jumlah_s2 = s2_a + s2_b + s2_c + s2_d + s2_e + s2_f
print("tamat s2 : " + str (jumlah_s2))
s1_a= 4
s1_b= 12
s1_c= 6
s1_d= 13
s1_e= 14
s1_f= 0
jumlah_s1 = s1_a + s1_b + s1_c + s1_d + s1_e + s1_f
print("tamat s1 : " + str (jumlah_s1))
sma_a= 12
sma_b= 17
sma_c= 5
sma_d= 20
sma_e= 11
sma_f= 75
jumlah_sma = sma_a + sma_b + sma_c + sma_d + sma_e + sma_f
print("tamat sma : " + str (jumlah_sma))
smp_a= 5
smp_b= 6
smp_c= 15
smp_d= 9
smp_e= 20
smp_f= 15
jumlah_smp = smp_a + smp_b + smp_c + smp_d + smp_e + smp_f
print("tamat smp : " + str (jumlah_smp))
sd_a= 1
sd_b= 8
sd_c= 0
sd_d= 19
sd_e= 10
sd_f= 1
jumlah_sd = sd_a + sd_b + sd_c + sd_d + sd_e + sd_f
print("tamat sd : " + str (jumlah_sd))
tdk_a= 2
tdk_b= 14
tdk_c= 3
tdk_d= 10
tdk_e= 0
tdk_f= 1
jumlah_tdk = tdk_a + tdk_b + tdk_c + tdk_d + tdk_e + tdk_f
print("tdk ketagui : " + str (jumlah_tdk))
print()
print("--soal no2--")
print()
s2_j = 17
s2_k= 0.25
hasil = (s2_j* s2_k)
print("bobot indeks mutu pendidikan : " + str (hasil))
s1_j = 49
s1_k= 0.20
hasil = (s1_j* s1_k)
print("bobot indeks mutu pendidikan : " + str (hasil))
sma_j = 140
sma_k= 0.15
hasil = (sma_j* sma_k)
print("bobot indeks mutu pendidikan : " + str (hasil))
smp_j = 70
smp_k= 0.10
hasil = (smp_j* smp_k)
print("bobot indeks mutu pendidikan : " + str (hasil))
sd_j = 39
sd_k= 0.05
hasil = (sd_j* sd_k)
print("bobot indeks mutu pendidikan : " + str (hasil))
tdk_j = 30
tdk_k= 0.03
hasil = (tdk_j* tdk_k)
print("bobot indeks mutu pendidikan : " + str (hasil))
print()
print("--soal no3--")
print()

print("===usia 70 ===")
usia1_70a= 0
usia2_70a=  0.25
hasil = (usia1_70a * usia2_70a)
print("bobot indeks mutu pendidikan s2 : " + str (hasil))
usia1_70b = 4
usia2_70b = 0.20
hasil = (usia1_70b * usia2_70b)
print("bobot indeks mutu pendidikan s1 : " + str (hasil))
usia1_70c= 12
usia2_70c= 0.15
hasil = (usia1_70c * usia2_70c)
print("bobot indeks mutu pendidikan sma : " + str (hasil))
usia1_70d= 5
usia2_70d= 0.10
hasil = (usia1_70d * usia2_70d)
print("bobot indeks mutu pendidikan smp : " + str (hasil))
usia1_70e= 1
usia2_70e= 0.05
hasil = (usia1_70e * usia2_70e)
print("bobot indeks mutu pendidikan sd: " + str (hasil))
usia1_70f= 2
usia2_70f= 0.03
hasil = (usia1_70f * usia2_70f)
print("bobot indeks mutu pendidikan : " + str (hasil))
a = 0.0
b = 0.8
c = 1.79
d = 0.5
e = 0.05
f = 0.06
hasil =(a + b) + (c + d) + (e + f)
print("jumlah bobot pada usia > 70: " + str (hasil))
print()

print("===usia 60 ===")
usia1_60a= 1
usia2_60a=  0.25
hasil = (usia1_60a * usia2_60a)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_60b = 12
usia2_60b = 0.20
hasil = (usia1_60b * usia2_60b)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_60c= 17
usia2_60c= 0.15
hasil = (usia1_60c * usia2_60c)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_60d= 6
usia2_60d= 0.10
hasil = (usia1_60d * usia2_60d)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_60e= 8
usia2_60e= 0.05
hasil = (usia1_60e * usia2_60e)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_60f= 16
usia2_60f= 0.03
hasil = (usia1_60f * usia2_60f)
print("bobot indeks mutu pendidikan : " + str (hasil))
a = 0.25
b = 2.40
c = 2.55
d = 0.60
e = 0.4
f = 0.48
hasil =(a + b) + (c + d) + (e + f)
print("jumlah bobot pada usia > 60: " + str (hasil))
print()
print("===usia 50 ===")
usia1_50a= 4
usia2_50a=  0.25
hasil = (usia1_50a * usia2_50a)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_50b = 6
usia2_50b = 0.20
hasil = (usia1_50b * usia2_50b)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_50c= 5
usia2_50c= 0.15
hasil = (usia1_50c * usia2_50c)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_50d= 15
usia2_50d= 0.10
hasil = (usia1_50d * usia2_50d)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_50e= 0
usia2_50e= 0.05
hasil = (usia1_50e * usia2_50e)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_50f= 3
usia2_50f= 0.03
hasil = (usia1_50f * usia2_50f)
print("bobot indeks mutu pendidikan : " + str (hasil))
a = 1.0
b = 1.20
c = 0.75
d = 1.5
e = 0.0
f = 0.09
hasil =(a + b) + (c + d) + (e + f)
print("jumlah bobot pada usia > 50: " + str (hasil))
print()

print("===usia 40 ===")
usia1_40a= 7
usia2_40a=  0.25
hasil = (usia1_40a * usia2_40a)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_40b = 13
usia2_40b = 0.20
hasil = (usia1_40b * usia2_40b)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_40c= 20
usia2_40c= 0.15
hasil = (usia1_40c * usia2_40c)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_40d= 9
usia2_40d= 0.10
hasil = (usia1_40d * usia2_40d)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_40e= 19
usia2_40e= 0.05
hasil = (usia1_40e * usia2_40e)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_40f= 10
usia2_40f= 0.03
hasil = (usia1_40f * usia2_40f)
print("bobot indeks mutu pendidikan : " + str (hasil))
a = 1.75
b = 2.6
c = 3.0
d = 0.9
e = 0.95
f = 0.3
hasil =(a + b) + (c + d) + (e + f)
print("jumlah bobot pada usia > 40: " + str (hasil))
print()

print("===usia 30 ===")
usia1_30a= 0
usia2_30a=  0.25
hasil = (usia1_30a * usia2_30a)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_30b = 4
usia2_30b = 0.20
hasil = (usia1_30b * usia2_30b)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_30c= 12
usia2_30c= 0.15
hasil = (usia1_30c * usia2_30c)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_30d= 5
usia2_30d= 0.10
hasil = (usia1_30d * usia2_30d)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_30e= 1
usia2_30e= 0.05
hasil = (usia1_30e * usia2_30e)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_30f= 2
usia2_30f= 0.03
hasil = (usia1_30f * usia2_30f)
print("bobot indeks mutu pendidikan : " + str (hasil))
a = 0.0
b = 0.8
c = 1.79
d = 0.5
e = 0.05
f = 0.03
hasil =(a + b) + (c + d) + (e + f)
print("jumlah bobot pada usia > 30: " + str (hasil))
print()

print("===usia 20 ===")
usia1_20a= 5
usia2_20a=  0.25
hasil = (usia1_20a * usia2_20a)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_20b = 14
usia2_20b = 0.20
hasil = (usia1_20b * usia2_20b)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_20c= 11
usia2_20c= 0.15
hasil = (usia1_20c * usia2_20c)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_20d= 20
usia2_20d= 0.10
hasil = (usia1_20d * usia2_20d)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_20e= 10
usia2_20e= 0.05
hasil = (usia1_20e * usia2_20e)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_20f= 0
usia2_20f= 0.03
hasil = (usia1_20f * usia2_20f)
print("bobot indeks mutu pendidikan : " + str (hasil))
a = 1.25
b = 2.80
c = 1.65
d = 2.0
e = 0.5
f = 0.0
hasil =(a + b) + (c + d) + (e + f)
print("jumlah bobot pada usia > 20: " + str (hasil))
print()

print("===usia 10 ===")
usia1_10a= 0
usia2_10a=  0.25
hasil = (usia1_10a * usia2_10a)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_10b = 0
usia2_10b = 0.20
hasil = (usia1_10b * usia2_10b)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_10c= 75
usia2_10c= 0.15
hasil = (usia1_10c * usia2_10c)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_10d= 15
usia2_10d= 0.10
hasil = (usia1_10d * usia2_10d)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_10e= 7
usia2_10e= 0.05
hasil = (usia1_10e * usia2_10e)
print("bobot indeks mutu pendidikan : " + str (hasil))
usia1_10f= 1
usia2_10f= 0.03
hasil = (usia1_10f * usia2_10f)
print("bobot indeks mutu pendidikan : " + str (hasil))
a = 0.0
b = 0.0
c = 11.25
d = 1.5
e = 0.35
f = 0.03
hasil =(a + b) + (c + d) + (e + f)
print("jumlah bobot pada usia > 10: " + str (hasil))
print()

print("--soal no4--")
print()
min = 3.1999999999999997
print("maka jumlah mutu indexs usia 70 adalah : " + str (min))

print("--soal no5--")
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['s2','s1','sma','smp','sd','tidak diketahui']
siswa = [17, 49, 140, 70, 39, 30  ]
ax.pie(siswa,labels=jurusan,autopct= '%1.2f%%')
plt.title("keseluruhan pendidikan ")
plt.show()
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['s2','s1','sma','smp','sd','tidak diketahui']
pengikut = [17, 49, 140, 70, 39, 30  ]
c = ['red', 'blue', 'green']
plt.title("keseluruhan pendidikan ")
plt.bar(eskul, pengikut, color = c)
plt.show()

print("=====rentan usia=====")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['usia > 70','usia > 60','usia > 50','usia > 40','usia > 30','usia > 20']
siswa = [24, 58, 33, 78, 60, 92  ]
ax.pie(siswa,labels=jurusan,autopct= '%1.2f%%')
plt.title("keseluruhan pada usai ")
plt.show()
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['usia > 70','usia > 60','usia > 50','usia > 40','usia > 30','usia > 20']
pengikut = [24, 58, 33, 78, 60, 92  ]
c = ['red', 'blue', 'green']
plt.title("keseluruhan pada usia ")
plt.bar(eskul, pengikut, color = c)
plt.show()
# Out:
# --soal no1--
#
# tamat s2 : 17
# tamat s1 : 49
# tamat sma : 140
# tamat smp : 70
# tamat sd : 39
# tdk ketagui : 30
#
# --soal no2--
#
# bobot indeks mutu pendidikan : 4.25
# bobot indeks mutu pendidikan : 9.8
# bobot indeks mutu pendidikan : 21.0
# bobot indeks mutu pendidikan : 7.0
# bobot indeks mutu pendidikan : 1.9500000000000002
# bobot indeks mutu pendidikan : 0.8999999999999999
#
# --soal no3--
#
# ===usia 70 ===
# bobot indeks mutu pendidikan s2 : 0.0
# bobot indeks mutu pendidikan s1 : 0.8
# bobot indeks mutu pendidikan sma : 1.7999999999999998
# bobot indeks mutu pendidikan smp : 0.5
# bobot indeks mutu pendidikan sd: 0.05
# bobot indeks mutu pendidikan : 0.06
# jumlah bobot pada usia > 70: 3.1999999999999997
#
# ===usia 60 ===
# bobot indeks mutu pendidikan : 0.25
# bobot indeks mutu pendidikan : 2.4000000000000004
# bobot indeks mutu pendidikan : 2.55
# bobot indeks mutu pendidikan : 0.6000000000000001
# bobot indeks mutu pendidikan : 0.4
# ...
